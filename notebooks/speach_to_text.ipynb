# %%
import whisper

# %%
audio_path = "data/Athena.m4a"
output_file_name = "transcription"

# %%
# Load the Whisper model (choose: tiny, base, small, medium, large)
model = whisper.load_model("tiny")    


print("Transcribing... this may take a few minutes for a 1h file.")

result = model.transcribe(audio_path)

# Print text
print(result["text"])

# Save transcript to file
with open(f"{output_file_name}.txt", "w", encoding="utf-8") as f:
    f.write(result["text"])
# Out:
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:07<00:00, 10.1MiB/s]
# Transcribing... this may take a few minutes for a 1h file.
# /home/dido/Documents/VSCodeProjects/speach_to_text/.venv/lib/python3.12/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
